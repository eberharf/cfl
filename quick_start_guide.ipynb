# %% [markdown]
# #### 11/2/20

# %% [markdown]
# # Quick Start Guide
# -----------------
# This notebook will show how to run a basic experiment using the `cfl` package. It will also explain the visual bars data and some background for CFL.
#
#
#
# Contents
# - Background (What is CFL?)
# - Importing the `cfl` package
# - Loading Data
# - Saving Results
# - Training and Predicting with a CFL object
# - Visualizing the results
# - Beyond the Basics: Training and predicting just the conditional density or just with clustering
# - Beyond the Basics: Loading Saved Weights

# %% [markdown]
# ## Background
#
# Causal Feature Learning (CFL) is an algorithm designed to construct macro-variables from low-level data in an unsupervised manner while accounting for the causal relationships between these macro-variables. Given low-level datasets, CFL aggregates them into two sets of macro-variables: a set of effects (e.g. emotional responses) and a set of potential causes (e.g. activity in regions of the brain).
#
#
# CFL is designed to take two data sets as input: `X`, which contains all the potential 'causal' features in the data, and `Y`, which contains all the potential 'effect' features in the data. In other words, CFL pre-supposes that all potential causes to discover are in `X` (but not all the features in `X` need be causally important).
#
# CFL learns the conditional probability distribution $P(Y|X)$ (or some reasonable proxy for this distibution). It then clusters together Xs for which the equivalence relation $P(Y|X=x_1) = P(Y|X=x_2)$ is (approximately) true, followed by clustering Ys for which the relation $P(Y=y_1|X) = P(Y=y_2|X)$ approximately holds. Thus, CFL works in two steps: first, estimating the conditional density; and second, clustering.
#
# As stated above, CFL creates macrovariables from the low-level data. These macrovariables are two sets of partitions, one each for the cause and effect space. In our implementation below, these partitions are represented by labels on each of the samples used to train the two models, as well as the trained models themselves, which can then be used to classify further predictions as being members of specific macrovariables.

# %%
#import standard pacakges 
import numpy as np #needed for reshaping arrays 
import matplotlib.pyplot as plt #for rendering plots

# %% [markdown]
# ## Importing the `cfl` package
#
# Type `import cfl` in order to import the entire `cfl` package, or import the specific modules you intend to use.

# %%
# importing cfl will import all of the sub-modules inside of cfl as well
import cfl

# you can also import specific files, functions, or classes
# into the local namespace 
from cfl.cfl_wrapper import make_CFL
from cfl.save.experiment_saver import ExperimentSaver
from cfl.dataset import Dataset

# %% [markdown]
# ## Visual Bars Data
#
# For this experiment, we will use the Visual Bars dataset (from Chalupka 2015).
#
# The causal dataset consists of a set of binary (black-and-white) images. These images each have a black background
# and contain white pixels of random noise. Each image may also contain either a white vertical and/or a horizontal bar.
#
# The effect dataset (aka the "Target") is, in this case, a single dimensional binary variable. In other words, there is only one variable in the target data set, and that variable can either be a "0" or a "1".
#
#
# The underlying causal structure used to generate the visual bars images includes two 'hidden variables', the contents of each image, and the target's value. The values of hidden variables are not observed directly in the data set, but they impact the values of variables that we do observe.
#
# The $H_{1}$ hidden variable being "on" deterministically causes a vertical bar to be present in the image. If the hidden variable is on, the vertical bar is present in the image. It also increases the probability that the target variable will be "on." The $H_{2}$ hidden variable causes a horizontal bar to be present in the image, but does not directly impact the value of the target. In an image, the presence of a horizontal bar increases the probability of the target being on, but the presence of a vertical bar does not directly increase the probability of the target being on.
#
# Below, these relationships are shown as a causal graph. The solid circles are the observed variables, the dotted lines are hidden (unobserved) variables, and the arrows denote a causal relationship from one variable to another.
#
# <img src="img/VisualBarsCausal.png" alt="causal graph for visual bars" height="200"/>
#
#
# Wow! All that's a little confusing. What does it mean?
#
# Basically, this means that there is confounding in our set-up! You can see in the image above that $H_{1}$ has influence on both the images and the target directly. And confounding makes disentangling the causal relationships a little more complicated.
#
#
# So we want CFL to separate the images in our data set into 4 observational classes: one for each combination of values for H1 and H2. This will allow later experimenters to intervene across these boundaries and determine which of the differences in the images are causally important (the horizontal bars) versus predictive but not causal (the vertical bars)
#
#
# The table below shows the 'ground truth' probability of the target value being on, given each possible state of the hidden variables. These values are used to generate the target values. We want to recover these probabilities as accurately as possible by the end of the density estimation step of CFL, and recover these four categories by the end of the clustering step.
#
# <img src="img/VisualBarsProbs.png" alt="probability table for visual bars" height="150"/>

# %% [markdown]
# ## Loading Visual Bars Data
#
# In order to create a visual bars data set (ie a set of images and associated target values), we need to import the file `generate_visual_bars_data.py`. If you are trying to generate the visual bars data from somewhere outside the root directory of the reposity, add the visual_bars_test directory path to the PYTHONPATH (same as you did for the `cfl` package) for easy importing.

# %%
#import the file to generate visual bars data 
import visual_bars_test.generate_visual_bars_data as vbd

# uncomment this line and use it instead if you have added visual_bars_test to the pythonpath
# import generate_visual_bars_data as vbd

# %% [markdown]
# In order to generate visual bars data, we set the number of images we want to generate (`n_samples`), the size of each image in pixels (`im_shape`), and the intensity of random noise in the image (`noise_lvl`). To have reproducible results, we also will set a random seed.

# %%
n_samples = 1000
im_shape = (10, 10)
noise_lvl= 0.03
set_seed = 180

# create visual bars data 
vb_data = vbd.VisualBarsData(n_samples=n_samples, im_shape = im_shape, noise_lvl=noise_lvl, set_random_seed=set_seed)

# visualize some example images 
vb_data.viewSingleImage()
vb_data.viewSingleImage()
vb_data.viewSingleImage()

# %% [markdown]
# We save the images to a variable `X` and the array of target behavior to a variable `Y`. Note that `X` and `Y` are aligned - they have the same number of observations, and the nth image in `X` corresponds to the nth target value in `Y`.

# %%
# retrieve the images and the target 
X = vb_data.getImages()
Y = vb_data.getTarget()

# X and Y have the same number of rows  
print(X.shape)
print(Y.shape)
print(X.shape[0]==Y.shape[0])
# Out:
# (1000, 10, 10)
# (1000,)
# True

# %% [markdown]
# Finally, we reshape the `X` and `Y` into the right shapes to be passed through the conditional density estimation (CDE) step of CFL. Because the density estimation model we will use, `CondExp`, takes in 1-dimensional input, we need to flatten the 2D images into 1D before passing `X` in. NOTE: not all CDEs need the same input shape! Most take in 1D inputs, but a convolutional neural net (CNN), take in 2-D input. If we were using a CNN, we would not flatten `X`.
#
# We then expand `Y` because Tensorflow expects 2 dimensions, where the first dimension is samples and the second is features. So expanding to 2 dimensions is makes the shape (n_samples, 1)instead of (n_samples,).

# %%
#reformat x, y into the right shape for the neural net 
X = np.reshape(X, (X.shape[0], X.shape[1]*X.shape[2])) 
Y = np.expand_dims(Y, -1)
print(X.shape)
print(Y.shape)
# Out:
# (1000, 100)
# (1000, 1)

# %% [markdown]
# ## Key Points: Loading Data
# - should have a data set X and a data set Y that are aligned (each row in X corresponds to the row with the same index in Y)
# - For most instances of CFL, X and Y should be reshaped st that each one is a 2D array, where the first dimension is samples/observations and the second dimension is all the features

# %% [markdown]
# ## Saving Results
#
# We will now set up an experiment saver. This will save not only the results from each step of CFL, but also the parameters input to CFL.
#
# We will also pass the X and Y data into a Dataset object. Then, every time we pass that Dataset through any part of the CFL pipeline, the results will automatically be stored in a directory associated with that Dataset.

# %%
# save experiment results from this CFL configuration across all datasets to 'results/visual_bars/experiment000x'
experiment_saver = ExperimentSaver('results/visual_bars')

# construct dataset. this will save all dataset-specific results to 'results/visual_bars/experiment000x/dataset0'
dataset0 = Dataset(X, Y, dataset_label='dataset0', experiment_saver=experiment_saver)
# Out:
# base_path 'results/visual_bars' does not exist, creating now.
# All results from this run will be saved to results/visual_bars\experiment0000

# %% [markdown]
# ## Training and Predicting with a CFL object
#
# Now we're ready to go!
#
# First, CFL takes in several sets of parameters, each in dictionary form:
# - `data_info`
# - `CDE_params`
# - `cluster_params`
#
# For further details on the meaning of these parameters, consult the documentation for the clusterer and the CondExp base class.
#
# Note that not all of the CDE_params listed here need to be specified - if they are not specified, default values will be provided.

# %%
# set all CFL parameters

# generic data parameters
data_info = { 'X_dims' : X.shape, 
              'Y_dims' : Y.shape } 

# conditional density estimator parameters
CDE_params = { 'batch_size'  : 128,
               'optimizer'   : 'adam',
               'n_epochs'    : 100,
               'verbose'     : 1,
               'opt_config'  : {'lr': 1e-4},
               'dense_units' : [1024, 1024, data_info['Y_dims'][1]],
               'activations' : ['linear', 'linear', 'linear'],
               'dropouts'    : [0.2, 0.5, 0.5], 
               'show_plot'   : False }

    
# clusterer parameters
cluster_params = { 'n_Xclusters' : 4, 
                   'n_Yclusters' : 4 }

# %% [markdown]
# Then we make the cfl object with the `make_CFL` function! This function allows you to create both parts of the cfl model in one step. It takes in the parameter dictionaries, and strings specifying which type of CDE/ clusterer to use.

# %%
# build CFL object! 
cfl_object = make_CFL(  data_info=data_info, 
                        CDE_type='CondExpMod', 
                        cluster_type='Kmeans', 
                        CDE_params=CDE_params, 
                        cluster_params=cluster_params,
                        experiment_saver=experiment_saver)
# Out:
# weights_path not specified in params, defaulting to None
# loss not specified in params, defaulting to mean_squared_error

# %% [markdown]
# We train the CFL object on our data.
# The results are in the form `(x labels, y labels, train loss, test loss)`.
# The x labels and y labels are the macrovariable labels for each sample in the X and Y data set, respectively,
# and the trian and test losses are the losses from the density estimation step of training.

# %%
train_results = cfl_object.train(dataset0, standardize=True)
# Out:
# Train on 750 samples, validate on 250 samples
# Epoch 1/100
# 750/750 [==============================] - 2s 3ms/sample - loss: 2.5113 - val_loss: 0.9655
# Epoch 2/100
# 750/750 [==============================] - 0s 566us/sample - loss: 2.3800 - val_loss: 0.8894
# Epoch 3/100
# 750/750 [==============================] - 0s 379us/sample - loss: 2.0657 - val_loss: 0.8379
# Epoch 4/100
# 750/750 [==============================] - 0s 197us/sample - loss: 1.8229 - val_loss: 0.8647
# Epoch 5/100
# 750/750 [==============================] - 0s 161us/sample - loss: 1.7216 - val_loss: 0.8544
# Epoch 6/100
# 750/750 [==============================] - 0s 308us/sample - loss: 1.8639 - val_loss: 0.7751
# Epoch 7/100
# 750/750 [==============================] - 0s 218us/sample - loss: 1.7372 - val_loss: 0.8197
# Epoch 8/100
# 750/750 [==============================] - 0s 259us/sample - loss: 2.0508 - val_loss: 0.8368
# Epoch 9/100
# 750/750 [==============================] - 0s 179us/sample - loss: 1.7241 - val_loss: 0.8584
# Epoch 10/100
# 750/750 [==============================] - 0s 176us/sample - loss: 2.0523 - val_loss: 0.7945
# Epoch 11/100
# 750/750 [==============================] - 0s 306us/sample - loss: 1.9087 - val_loss: 0.7511
# Epoch 12/100
# 750/750 [==============================] - 0s 384us/sample - loss: 1.9080 - val_loss: 0.7396
# Epoch 13/100
# 750/750 [==============================] - 0s 204us/sample - loss: 1.8686 - val_loss: 0.7499
# Epoch 14/100
# 750/750 [==============================] - 0s 174us/sample - loss: 1.6741 - val_loss: 0.7763
# Epoch 15/100
# 750/750 [==============================] - 0s 172us/sample - loss: 1.7753 - val_loss: 0.7752
# Epoch 16/100
# 750/750 [==============================] - 0s 178us/sample - loss: 1.8480 - val_loss: 0.8088
# Epoch 17/100
# 750/750 [==============================] - 0s 185us/sample - loss: 1.6665 - val_loss: 0.8307
# Epoch 18/100
# 750/750 [==============================] - 0s 215us/sample - loss: 1.7966 - val_loss: 0.7737
# Epoch 19/100
# 750/750 [==============================] - 0s 285us/sample - loss: 1.8512 - val_loss: 0.7407
# Epoch 20/100
# 750/750 [==============================] - 0s 209us/sample - loss: 1.8067 - val_loss: 0.7589
# Epoch 21/100
# 750/750 [==============================] - 0s 235us/sample - loss: 1.7038 - val_loss: 0.8042
# Epoch 22/100
# 750/750 [==============================] - 0s 227us/sample - loss: 1.8699 - val_loss: 0.7862
# Epoch 23/100
# 750/750 [==============================] - 0s 260us/sample - loss: 1.7316 - val_loss: 0.7786
# Epoch 24/100
# 750/750 [==============================] - 0s 265us/sample - loss: 1.7583 - val_loss: 0.7491
# Epoch 25/100
# 750/750 [==============================] - 0s 269us/sample - loss: 1.7908 - val_loss: 0.7509
# Epoch 26/100
# 750/750 [==============================] - 0s 218us/sample - loss: 1.6231 - val_loss: 0.8246
# Epoch 27/100
# 750/750 [==============================] - 0s 257us/sample - loss: 1.8092 - val_loss: 0.8575
# Epoch 28/100
# 750/750 [==============================] - 0s 297us/sample - loss: 1.4559 - val_loss: 0.8133
# Epoch 29/100
# 750/750 [==============================] - 0s 299us/sample - loss: 1.6541 - val_loss: 0.7667
# Epoch 30/100
# 750/750 [==============================] - 0s 282us/sample - loss: 1.6657 - val_loss: 0.7493
# Epoch 31/100
# 750/750 [==============================] - 0s 264us/sample - loss: 1.4635 - val_loss: 0.7684
# Epoch 32/100
# 750/750 [==============================] - 0s 295us/sample - loss: 1.6905 - val_loss: 0.7835
# Epoch 33/100
# 750/750 [==============================] - 0s 250us/sample - loss: 1.6665 - val_loss: 0.7769
# Epoch 34/100
# 750/750 [==============================] - 0s 326us/sample - loss: 1.4901 - val_loss: 0.7671
# Epoch 35/100
# 750/750 [==============================] - 0s 267us/sample - loss: 1.5252 - val_loss: 0.7771
# Epoch 36/100
# 750/750 [==============================] - 0s 280us/sample - loss: 1.4048 - val_loss: 0.7828
# Epoch 37/100
# 750/750 [==============================] - 0s 286us/sample - loss: 1.6930 - val_loss: 0.7601
# Epoch 38/100
# 750/750 [==============================] - 0s 283us/sample - loss: 1.5859 - val_loss: 0.7886
# Epoch 39/100
# 750/750 [==============================] - 0s 288us/sample - loss: 1.6461 - val_loss: 0.8042
# Epoch 40/100
# 750/750 [==============================] - 0s 291us/sample - loss: 1.6408 - val_loss: 0.8108
# Epoch 41/100
# 750/750 [==============================] - 0s 317us/sample - loss: 1.3645 - val_loss: 0.8085
# Epoch 42/100
# 750/750 [==============================] - 0s 379us/sample - loss: 1.6548 - val_loss: 0.7596
# Epoch 43/100
# 750/750 [==============================] - 0s 261us/sample - loss: 1.2747 - val_loss: 0.7647
# Epoch 44/100
# 750/750 [==============================] - 0s 297us/sample - loss: 1.5930 - val_loss: 0.7660
# Epoch 45/100
# 750/750 [==============================] - 0s 268us/sample - loss: 1.6041 - val_loss: 0.7767
# Epoch 46/100
# 750/750 [==============================] - 0s 269us/sample - loss: 1.4248 - val_loss: 0.8165
# Epoch 47/100
# 750/750 [==============================] - 0s 237us/sample - loss: 1.3903 - val_loss: 0.7881
# Epoch 48/100
# 750/750 [==============================] - 0s 246us/sample - loss: 1.4388 - val_loss: 0.7694
# Epoch 49/100
# 750/750 [==============================] - 0s 268us/sample - loss: 1.5448 - val_loss: 0.7414
# Epoch 50/100
# 750/750 [==============================] - 0s 248us/sample - loss: 1.4473 - val_loss: 0.7642
# Epoch 51/100
# 750/750 [==============================] - 0s 243us/sample - loss: 1.4833 - val_loss: 0.8088
# Epoch 52/100
# 750/750 [==============================] - 0s 318us/sample - loss: 1.5614 - val_loss: 0.8375
# Epoch 53/100
# 750/750 [==============================] - 0s 299us/sample - loss: 1.4456 - val_loss: 0.8240
# Epoch 54/100
# 750/750 [==============================] - 0s 266us/sample - loss: 1.4627 - val_loss: 0.7695
# Epoch 55/100
# 750/750 [==============================] - 0s 219us/sample - loss: 1.4835 - val_loss: 0.7468
# Epoch 56/100
# 750/750 [==============================] - 0s 212us/sample - loss: 1.3328 - val_loss: 0.8067
# Epoch 57/100
# 750/750 [==============================] - 0s 221us/sample - loss: 1.3407 - val_loss: 0.8575
# Epoch 58/100
# 750/750 [==============================] - 0s 245us/sample - loss: 1.5127 - val_loss: 0.7521
# Epoch 59/100
# 750/750 [==============================] - 0s 514us/sample - loss: 1.3702 - val_loss: 0.7245
# Epoch 60/100
# 750/750 [==============================] - 0s 272us/sample - loss: 1.3081 - val_loss: 0.7246
# Epoch 61/100
# 750/750 [==============================] - 0s 229us/sample - loss: 1.4147 - val_loss: 0.7567
# Epoch 62/100
# 750/750 [==============================] - 0s 253us/sample - loss: 1.4555 - val_loss: 0.7712
# Epoch 63/100
# 750/750 [==============================] - 0s 211us/sample - loss: 1.5432 - val_loss: 0.7478
# Epoch 64/100
# 750/750 [==============================] - 0s 241us/sample - loss: 1.4089 - val_loss: 0.7421
# Epoch 65/100
# 750/750 [==============================] - 0s 240us/sample - loss: 1.3582 - val_loss: 0.7743
# Epoch 66/100
# 750/750 [==============================] - 0s 210us/sample - loss: 1.3215 - val_loss: 0.7818
# Epoch 67/100
# 750/750 [==============================] - 0s 200us/sample - loss: 1.4421 - val_loss: 0.7483
# Epoch 68/100
# 750/750 [==============================] - 0s 279us/sample - loss: 1.3070 - val_loss: 0.7557
# Epoch 69/100
# 750/750 [==============================] - 0s 260us/sample - loss: 1.0971 - val_loss: 0.7318
# Epoch 70/100
# 750/750 [==============================] - 0s 407us/sample - loss: 1.3713 - val_loss: 0.6948
# Epoch 71/100
# 750/750 [==============================] - 0s 334us/sample - loss: 1.3785 - val_loss: 0.7271
# Epoch 72/100
# 750/750 [==============================] - 0s 205us/sample - loss: 1.2941 - val_loss: 0.7740
# Epoch 73/100
# 750/750 [==============================] - 0s 270us/sample - loss: 1.3497 - val_loss: 0.7674
# Epoch 74/100
# 750/750 [==============================] - 0s 287us/sample - loss: 1.2473 - val_loss: 0.7413
# Epoch 75/100
# 750/750 [==============================] - 0s 252us/sample - loss: 1.2810 - val_loss: 0.7112
# Epoch 76/100
# 750/750 [==============================] - 0s 271us/sample - loss: 1.3671 - val_loss: 0.7513
# Epoch 77/100
# 750/750 [==============================] - 0s 280us/sample - loss: 1.2603 - val_loss: 0.7747
# Epoch 78/100
# 750/750 [==============================] - 0s 248us/sample - loss: 1.2494 - val_loss: 0.7709
# Epoch 79/100
# 750/750 [==============================] - 0s 248us/sample - loss: 1.3067 - val_loss: 0.7378
# Epoch 80/100
# 750/750 [==============================] - 0s 217us/sample - loss: 1.3488 - val_loss: 0.7279
# Epoch 81/100
# 750/750 [==============================] - 0s 219us/sample - loss: 1.2948 - val_loss: 0.7734
# Epoch 82/100
# 750/750 [==============================] - 0s 259us/sample - loss: 1.3036 - val_loss: 0.7984
# Epoch 83/100
# 750/750 [==============================] - 0s 277us/sample - loss: 1.1998 - val_loss: 0.7711
# Epoch 84/100
# 750/750 [==============================] - 0s 322us/sample - loss: 1.2395 - val_loss: 0.7710
# Epoch 85/100
# 750/750 [==============================] - 0s 271us/sample - loss: 1.3311 - val_loss: 0.7739
# Epoch 86/100
# 750/750 [==============================] - 0s 205us/sample - loss: 1.2857 - val_loss: 0.7888
# Epoch 87/100
# 750/750 [==============================] - 0s 437us/sample - loss: 1.2662 - val_loss: 0.7908
# Epoch 88/100
# 750/750 [==============================] - 0s 390us/sample - loss: 1.2227 - val_loss: 0.7876
# Epoch 89/100
# 750/750 [==============================] - 0s 317us/sample - loss: 1.1971 - val_loss: 0.7695
# Epoch 90/100
# 750/750 [==============================] - 0s 204us/sample - loss: 1.4356 - val_loss: 0.7614
# Epoch 91/100
# 750/750 [==============================] - 0s 250us/sample - loss: 1.1258 - val_loss: 0.7847
# Epoch 92/100
# 750/750 [==============================] - 0s 378us/sample - loss: 1.2313 - val_loss: 0.7866
# Epoch 93/100
# 750/750 [==============================] - 0s 286us/sample - loss: 1.3138 - val_loss: 0.7732
# Epoch 94/100
# 750/750 [==============================] - 0s 207us/sample - loss: 1.1425 - val_loss: 0.7545
# Epoch 95/100
# 750/750 [==============================] - 0s 184us/sample - loss: 1.2229 - val_loss: 0.7699
# Epoch 96/100
# 750/750 [==============================] - 0s 216us/sample - loss: 1.2547 - val_loss: 0.7774
# Epoch 97/100
# 750/750 [==============================] - 0s 215us/sample - loss: 1.1768 - val_loss: 0.7611
# Epoch 98/100
# 750/750 [==============================] - 0s 238us/sample - loss: 1.1893 - val_loss: 0.7286
# Epoch 99/100
# 750/750 [==============================] - 0s 208us/sample - loss: 1.2229 - val_loss: 0.7284
# Epoch 100/100
# 750/750 [==============================] - 0s 245us/sample - loss: 1.2474 - val_loss: 0.7620
# Loading parameters from  results/visual_bars\experiment0000\dataset0\checkpoints/best_weights
# 100%|██████████| 1000/1000 [00:00<00:00, 2694.02it/s]

# %% [markdown]
# To predict on different data using the previously trained model, we just create a second data set with the same experiment_saver, and call the predict method on that new dataset:

# %%
# make second dataset for prediction
# note: drawing from the same data as dataset0 for sake of demonstration (you would probably use different data)
dataset1 = Dataset(X[:100,:], Y[:100,:], dataset_label='dataset1', experiment_saver=experiment_saver) 

pyx = cfl_object.predict(dataset1)
# Out:
# 100%|██████████| 100/100 [00:00<00:00, 2898.80it/s]

# %% [markdown]
# ## Visualize Results
# We can view some images with their predicted label using the `viewImages` function. As we can see, the results are pretty inconsistent - multiple images that should be in the same class are part of different classes. This is in part because our sample size is not quite large enough for CFL to learn it very well. Try this experiment again with a larger sample size and see how the results change. You can also try with a different type of density estimator.

# %%
vb_data.viewImages(n_images=50, x_lbls=train_results[0][:50])

# %% [markdown]
# ## Beyond the Basics: Training and predicting with just the conditional density or just with clustering
#
# In some cases, you may not want to perform both steps of CFL on your data, but rather just one of the steps. In that case, you need to make the CDE or clusterer object individually.
#
# The commands to train and predict with a component of the CFL follow the same pattern as with the full CFL.

# %%
# generic data parameters
data_info = { 'X_dims' : X.shape, 
              'Y_dims' : Y.shape } 

# conditional density estimator parameters (same as before)
CDE_params = { 'batch_size'  : 128,
               'optimizer'   : 'adam',
               'n_epochs'    : 100,
               'verbose'     : 1,
               'dense_units' : [1024, 1024, data_info['Y_dims'][1]],
               'activations' : ['linear', 'linear', 'linear'],
               'dropouts'    : [0.2, 0.5, 0.5], 
               'show_plot'   : False }

# construct a CDE object (no saver specified - results will not be saved)
CDE_object = cfl.density_estimation_methods.condExp.CondExp(data_info, CDE_params)

# training a CDE object is very straightforward! 
CDE_object.train(dataset0, standardize=False, best=True)

#predicting with it is also easy! 
pyx = CDE_object.predict(dataset0)
# Out:
# opt_config not specified in params, defaulting to {}
# weights_path not specified in params, defaulting to None
# loss not specified in params, defaulting to mean_squared_error
# You have not provided an ExperimentSaver. Your may continue to run CFL but your configuration will not be saved.
# Train on 750 samples, validate on 250 samples
# Epoch 1/100
# 750/750 [==============================] - 2s 3ms/sample - loss: 4.7610 - val_loss: 0.6632
# Epoch 2/100
# 750/750 [==============================] - 0s 136us/sample - loss: 4.0116 - val_loss: 0.4793
# Epoch 3/100
# 750/750 [==============================] - 0s 142us/sample - loss: 4.0315 - val_loss: 0.3857
# Epoch 4/100
# 750/750 [==============================] - 0s 170us/sample - loss: 3.1714 - val_loss: 0.3285
# Epoch 5/100
# 750/750 [==============================] - 0s 308us/sample - loss: 2.7593 - val_loss: 0.2998
# Epoch 6/100
# 750/750 [==============================] - 0s 223us/sample - loss: 2.5746 - val_loss: 0.2720
# Epoch 7/100
# 750/750 [==============================] - 0s 142us/sample - loss: 2.2838 - val_loss: 0.2447
# Epoch 8/100
# 750/750 [==============================] - 0s 174us/sample - loss: 2.0960 - val_loss: 0.2329
# Epoch 9/100
# 750/750 [==============================] - 0s 157us/sample - loss: 1.8734 - val_loss: 0.2327
# Epoch 10/100
# 750/750 [==============================] - 0s 147us/sample - loss: 1.7973 - val_loss: 0.2233
# Epoch 11/100
# 750/750 [==============================] - 0s 154us/sample - loss: 1.7602 - val_loss: 0.2129
# Epoch 12/100
# 750/750 [==============================] - 0s 295us/sample - loss: 1.5863 - val_loss: 0.2066
# Epoch 13/100
# 750/750 [==============================] - 0s 319us/sample - loss: 1.7717 - val_loss: 0.2039
# Epoch 14/100
# 750/750 [==============================] - 0s 143us/sample - loss: 1.5011 - val_loss: 0.2046
# Epoch 15/100
# 750/750 [==============================] - 0s 136us/sample - loss: 1.5267 - val_loss: 0.2042
# Epoch 16/100
# 750/750 [==============================] - 0s 265us/sample - loss: 1.4915 - val_loss: 0.2015
# Epoch 17/100
# 750/750 [==============================] - 0s 151us/sample - loss: 1.1560 - val_loss: 0.2015
# Epoch 18/100
# 750/750 [==============================] - 0s 142us/sample - loss: 1.3661 - val_loss: 0.2016
# Epoch 19/100
# 750/750 [==============================] - 0s 309us/sample - loss: 1.3472 - val_loss: 0.2003
# Epoch 20/100
# 750/750 [==============================] - 0s 156us/sample - loss: 1.1191 - val_loss: 0.1958
# Epoch 21/100
# 750/750 [==============================] - 0s 144us/sample - loss: 1.1073 - val_loss: 0.1915
# Epoch 22/100
# 750/750 [==============================] - 0s 280us/sample - loss: 1.0832 - val_loss: 0.1881
# Epoch 23/100
# 750/750 [==============================] - 0s 158us/sample - loss: 0.9758 - val_loss: 0.1837
# Epoch 24/100
# 750/750 [==============================] - 0s 108us/sample - loss: 1.0599 - val_loss: 0.1825
# Epoch 25/100
# 750/750 [==============================] - 0s 81us/sample - loss: 0.9176 - val_loss: 0.1858
# Epoch 26/100
# 750/750 [==============================] - 0s 94us/sample - loss: 0.8583 - val_loss: 0.1864
# Epoch 27/100
# 750/750 [==============================] - 0s 94us/sample - loss: 0.9895 - val_loss: 0.1839
# Epoch 28/100
# 750/750 [==============================] - 0s 180us/sample - loss: 0.9280 - val_loss: 0.1823
# Epoch 29/100
# 750/750 [==============================] - 0s 127us/sample - loss: 0.8217 - val_loss: 0.1809
# Epoch 30/100
# 750/750 [==============================] - 0s 154us/sample - loss: 0.9054 - val_loss: 0.1793
# Epoch 31/100
# 750/750 [==============================] - 0s 224us/sample - loss: 0.8155 - val_loss: 0.1792
# Epoch 32/100
# 750/750 [==============================] - 0s 120us/sample - loss: 0.9106 - val_loss: 0.1797
# Epoch 33/100
# 750/750 [==============================] - 0s 122us/sample - loss: 0.8052 - val_loss: 0.1806
# Epoch 34/100
# 750/750 [==============================] - 0s 68us/sample - loss: 0.7217 - val_loss: 0.1801
# Epoch 35/100
# 750/750 [==============================] - 0s 57us/sample - loss: 0.7078 - val_loss: 0.1806
# Epoch 36/100
# 750/750 [==============================] - 0s 130us/sample - loss: 0.6828 - val_loss: 0.1791
# Epoch 37/100
# 750/750 [==============================] - 0s 67us/sample - loss: 0.6979 - val_loss: 0.1791
# Epoch 38/100
# 750/750 [==============================] - 0s 75us/sample - loss: 0.6863 - val_loss: 0.1814
# Epoch 39/100
# 750/750 [==============================] - 0s 65us/sample - loss: 0.6793 - val_loss: 0.1831
# Epoch 40/100
# 750/750 [==============================] - 0s 64us/sample - loss: 0.6485 - val_loss: 0.1842
# Epoch 41/100
# 750/750 [==============================] - 0s 71us/sample - loss: 0.6601 - val_loss: 0.1835
# Epoch 42/100
# 750/750 [==============================] - 0s 67us/sample - loss: 0.6306 - val_loss: 0.1818
# Epoch 43/100
# 750/750 [==============================] - 0s 66us/sample - loss: 0.6814 - val_loss: 0.1808
# Epoch 44/100
# 750/750 [==============================] - 0s 142us/sample - loss: 0.5748 - val_loss: 0.1790
# Epoch 45/100
# 750/750 [==============================] - 0s 164us/sample - loss: 0.6587 - val_loss: 0.1769
# Epoch 46/100
# 750/750 [==============================] - 0s 235us/sample - loss: 0.5512 - val_loss: 0.1756
# Epoch 47/100
# 750/750 [==============================] - 0s 117us/sample - loss: 0.5167 - val_loss: 0.1769
# Epoch 48/100
# 750/750 [==============================] - 0s 101us/sample - loss: 0.6206 - val_loss: 0.1793
# Epoch 49/100
# 750/750 [==============================] - 0s 57us/sample - loss: 0.4996 - val_loss: 0.1813
# Epoch 50/100
# 750/750 [==============================] - 0s 55us/sample - loss: 0.5323 - val_loss: 0.1824
# Epoch 51/100
# 750/750 [==============================] - 0s 53us/sample - loss: 0.5421 - val_loss: 0.1829
# Epoch 52/100
# 750/750 [==============================] - 0s 52us/sample - loss: 0.5629 - val_loss: 0.1825
# Epoch 53/100
# 750/750 [==============================] - 0s 55us/sample - loss: 0.5070 - val_loss: 0.1814
# Epoch 54/100
# 750/750 [==============================] - 0s 58us/sample - loss: 0.5378 - val_loss: 0.1817
# Epoch 55/100
# 750/750 [==============================] - 0s 56us/sample - loss: 0.5030 - val_loss: 0.1813
# Epoch 56/100
# 750/750 [==============================] - 0s 46us/sample - loss: 0.5040 - val_loss: 0.1795
# Epoch 57/100
# 750/750 [==============================] - 0s 48us/sample - loss: 0.5049 - val_loss: 0.1771
# Epoch 58/100
# 750/750 [==============================] - 0s 51us/sample - loss: 0.4521 - val_loss: 0.1758
# Epoch 59/100
# 750/750 [==============================] - 0s 49us/sample - loss: 0.4730 - val_loss: 0.1756
# Epoch 60/100
# 750/750 [==============================] - 0s 59us/sample - loss: 0.4828 - val_loss: 0.1765
# Epoch 61/100
# 750/750 [==============================] - 0s 57us/sample - loss: 0.4769 - val_loss: 0.1775
# Epoch 62/100
# 750/750 [==============================] - 0s 49us/sample - loss: 0.4454 - val_loss: 0.1786
# Epoch 63/100
# 750/750 [==============================] - 0s 50us/sample - loss: 0.4428 - val_loss: 0.1792
# Epoch 64/100
# 750/750 [==============================] - 0s 48us/sample - loss: 0.4744 - val_loss: 0.1800
# Epoch 65/100
# 750/750 [==============================] - 0s 58us/sample - loss: 0.4760 - val_loss: 0.1803
# Epoch 66/100
# 750/750 [==============================] - 0s 51us/sample - loss: 0.4464 - val_loss: 0.1804
# Epoch 67/100
# 750/750 [==============================] - 0s 56us/sample - loss: 0.4060 - val_loss: 0.1791
# Epoch 68/100
# 750/750 [==============================] - 0s 51us/sample - loss: 0.4349 - val_loss: 0.1783
# Epoch 69/100
# 750/750 [==============================] - 0s 51us/sample - loss: 0.4196 - val_loss: 0.1772
# Epoch 70/100
# 750/750 [==============================] - 0s 110us/sample - loss: 0.4118 - val_loss: 0.1760
# Epoch 71/100
# 750/750 [==============================] - 0s 56us/sample - loss: 0.3771 - val_loss: 0.1756
# Epoch 72/100
# 750/750 [==============================] - 0s 51us/sample - loss: 0.4130 - val_loss: 0.1764
# Epoch 73/100
# 750/750 [==============================] - 0s 43us/sample - loss: 0.4286 - val_loss: 0.1772
# Epoch 74/100
# 750/750 [==============================] - 0s 43us/sample - loss: 0.3906 - val_loss: 0.1772
# Epoch 75/100
# 750/750 [==============================] - 0s 41us/sample - loss: 0.4084 - val_loss: 0.1774
# Epoch 76/100
# 750/750 [==============================] - 0s 45us/sample - loss: 0.4034 - val_loss: 0.1785
# Epoch 77/100
# 750/750 [==============================] - 0s 58us/sample - loss: 0.4315 - val_loss: 0.1802
# Epoch 78/100
# 750/750 [==============================] - 0s 53us/sample - loss: 0.3834 - val_loss: 0.1809
# Epoch 79/100
# 750/750 [==============================] - 0s 52us/sample - loss: 0.3734 - val_loss: 0.1809
# Epoch 80/100
# 750/750 [==============================] - 0s 47us/sample - loss: 0.3937 - val_loss: 0.1809
# Epoch 81/100
# 750/750 [==============================] - 0s 46us/sample - loss: 0.3356 - val_loss: 0.1788
# Epoch 82/100
# 750/750 [==============================] - 0s 46us/sample - loss: 0.3585 - val_loss: 0.1769
# Epoch 83/100
# 750/750 [==============================] - 0s 111us/sample - loss: 0.3883 - val_loss: 0.1755
# Epoch 84/100
# 750/750 [==============================] - 0s 45us/sample - loss: 0.3731 - val_loss: 0.1759
# Epoch 85/100
# 750/750 [==============================] - 0s 49us/sample - loss: 0.3544 - val_loss: 0.1763
# Epoch 86/100
# 750/750 [==============================] - 0s 46us/sample - loss: 0.3656 - val_loss: 0.1769
# Epoch 87/100
# 750/750 [==============================] - 0s 50us/sample - loss: 0.3514 - val_loss: 0.1770
# Epoch 88/100
# 750/750 [==============================] - 0s 44us/sample - loss: 0.3754 - val_loss: 0.1771
# Epoch 89/100
# 750/750 [==============================] - 0s 52us/sample - loss: 0.3606 - val_loss: 0.1762
# Epoch 90/100
# 750/750 [==============================] - 0s 50us/sample - loss: 0.3532 - val_loss: 0.1758
# Epoch 91/100
# 750/750 [==============================] - 0s 55us/sample - loss: 0.3508 - val_loss: 0.1757
# Epoch 92/100
# 750/750 [==============================] - 0s 53us/sample - loss: 0.3298 - val_loss: 0.1756
# Epoch 93/100
# 750/750 [==============================] - 0s 51us/sample - loss: 0.3381 - val_loss: 0.1757
# Epoch 94/100
# 750/750 [==============================] - 0s 142us/sample - loss: 0.3294 - val_loss: 0.1754
# Epoch 95/100
# 750/750 [==============================] - 0s 118us/sample - loss: 0.3420 - val_loss: 0.1756
# Epoch 96/100
# 750/750 [==============================] - 0s 65us/sample - loss: 0.3394 - val_loss: 0.1756
# Epoch 97/100
# 750/750 [==============================] - 0s 61us/sample - loss: 0.3125 - val_loss: 0.1758
# Epoch 98/100
# 750/750 [==============================] - 0s 58us/sample - loss: 0.3187 - val_loss: 0.1756
# Epoch 99/100
# 750/750 [==============================] - 0s 55us/sample - loss: 0.3107 - val_loss: 0.1758
# Epoch 100/100
# 750/750 [==============================] - 0s 55us/sample - loss: 0.3007 - val_loss: 0.1757
# Loading parameters from  results/visual_bars\experiment0000\dataset0\checkpoints/best_weights

# %%
# create a scatter plot showing conditional expectation of the target, as predicted by the CDE, 
# colored by ground truth class  
truth = vb_data.getGroundTruth()
fig = plt.figure()
plot_idx = np.random.choice(pyx.shape[0], 1000, replace=False)
plt.scatter(range(1000), pyx[plot_idx], c=truth[plot_idx])
fig.show()

for i in range(4):
    print('Average prediction for x-class {}: {:.2f}'.format(i, np.mean(pyx[truth==i])))
# Out:
# Average prediction for x-class 0: 0.32
# Average prediction for x-class 1: 0.53
# Average prediction for x-class 2: 0.53
# Average prediction for x-class 3: 0.73

# %% [markdown]
# However, what input and output each component needs depends on which step you're using:
#
# <img src="img/SampleCFLworkflow.png" alt="sample CFL workflow, showing inputs and outputs of each step" height="200"/>
#
# So if you are working with just the clusterer, you need to input the conditional expectations, not the dataset!

# %% [markdown]
# ## Beyond the Basics: Loading Saved Results
#
# You can load a previously trained conditional density model by specifying a `weights_path` in the CDE_params dict. This can be helpful in the case where we want to tune the clusterer, but don't want to wait for the CDE to train every time we retrain the clusterer.
#
#
# Note: in the future, we will implement the ability to load parameters and the clusterer model from previous runs, but those methods doesn't exist at the moment.

# %%
# construct dataset. this will save all dataset-specific results to 'results/visual_bars/experiment000x/dataset0'
dataset2 = Dataset(X, Y, dataset_label='dataset0', experiment_saver=experiment_saver)

# generic data parameters
data_info = { 'X_dims' : X.shape, 
              'Y_dims' : Y.shape } 


#include weights_path as a parameter to load saved weights from that path 
CDE_params_load_weights = { 'weights_path': 'results/visual_bars/experiment0000/dataset0/checkpoints/best_weights',  
               'batch_size'  : 128,
               'optimizer'   : 'adam',
               'n_epochs'    : 100,
               'verbose'     : 1,
               'opt_config'  : {'lr': 1e-4},
               'dense_units' : [1024, 1024, data_info['Y_dims'][1]],
               'activations' : ['linear', 'linear', 'linear'],
               'dropouts'    : [0.2, 0.5, 0.5], 
               'show_plot'   : False }


CDE_params = {"batch_size": 128, "optimizer": "adam", "n_epochs": 100, "verbose": True, "opt_config": {"lr": 0.0001}, "dense_units": [1024, 1024, 1], "activations": ["linear", "linear", "linear"], "dropouts": [0.2, 0.5, 0.5], "show_plot": False, "weights_path": None, "loss": "mean_squared_error", "model_name": "CondExpMod"}


# construct a CDE object 
CDE_object2 = cfl.density_estimation_methods.condExpMod.CondExpMod(data_info, CDE_params_load_weights, experiment_saver=experiment_saver)

# when we try to train, we see this CDE has already been trained! 
CDE_object2.train(dataset2, standardize=False, best=True)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-61-888f8a30b10d> in <module>
#       1 # construct dataset. this will save all dataset-specific results to 'results/visual_bars/experiment000x/dataset0'
# ----> 2 dataset2 = Dataset(X, Y, dataset_label='dataset0', experiment_saver=experiment_saver)
#       3
#       4 # generic data parameters
#       5 data_info = { 'X_dims' : X.shape,
#
# c:\Users\yumen\Documents\Schmidt Academy\cfl\cfl\dataset.py in __init__(self, X, Y, dataset_label, experiment_saver)
#      10         self.saver = None
#      11         if self.to_save:
# ---> 12             self.saver = experiment_saver.get_new_dataset_saver(dataset_label)
#      13         self.pyx = None
#      14
#
# c:\Users\yumen\Documents\Schmidt Academy\cfl\cfl\save\experiment_saver.py in get_new_dataset_saver(self, dataset_label)
#      32
#      33     def get_new_dataset_saver(self, dataset_label):
# ---> 34         return DatasetSaver(os.path.join(self.experiment_path, dataset_label))
#      35
#      36     def get_save_path(self, fn):
#
# c:\Users\yumen\Documents\Schmidt Academy\cfl\cfl\save\dataset_saver.py in __init__(self, save_path)
#       5     def __init__(self, save_path):
#       6         self.save_path = save_path
# ----> 7         self.setup_dataset_dir()
#       8
#       9     def setup_dataset_dir(self):
#
# c:\Users\yumen\Documents\Schmidt Academy\cfl\cfl\save\dataset_saver.py in setup_dataset_dir(self)
#      15
#      16         # make sure we're not overriding a preexisting dir
# ---> 17         assert not os.path.exists(self.save_path), "You have already saved results at {}". format(self.save_path)
#      18
#      19         # make save dir for this dataset
#
# AssertionError: You have already saved results at results/visual_bars\experiment0000\dataset0
