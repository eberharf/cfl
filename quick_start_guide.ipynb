# %%
# 11/2/20

# %% [markdown]
# # Quick Start Guide
# -----------------
# This notebook will show how to run a basic experiment using the `cfl` package. It will also explain the visual bars data and some background for CFL.
#
#
#
# Contents
# - Background (What is CFL?)
# - Importing the `cfl` package
# - Loading Data
# - Saving Results
# - Training and Predicting with a CFL object
# - Visualizing the results
# - Training and predicting just the conditional density or just with clustering

# %% [markdown]
# ## Background
#
# Causal Feature Learning (CFL) is an algorithm designed to construct macro-variables from low-level data in an unsupervised manner while accounting for the causal relationships between these macro-variables. Given low-level datasets, CFL aggregates them into two sets of macro-variables: a set of effects (e.g. emotional responses) and a set of potential causes (e.g. activity in regions of the brain).
#
#
# CFL is designed to take two data sets as input: `X`, which contains all the potential 'causal' features in the data, and `Y`, which contains all the potential 'effect' features in the data. In other words, CFL pre-supposes that all potential causes to discover are in `X` (but not all the features in `X` need be causally important).
#
# CFL learns the conditional probability distribution $P(Y|X)$ (or some reasonable proxy for this distibution). It then clusters together Xs for which the equivalence relation $P(Y|X=x_1) = P(Y|X=x_2)$ is (approximately) true, followed by clustering Ys for which the relation $P(Y=y_1|X) = P(Y=y_2|X)$ approximately holds. Thus, CFL works in two steps: first, estimating the conditional density; and second, clustering.
#
# As stated above, CFL creates macrovariables from the low-level data. These macrovariables are two sets of partitions, one each for the cause and effect space. In our implementation below, these partitions are represented by labels on each of the samples used to train the two models, as well as the trained models themselves, which can then be used to classify further predictions as being members of specific macrovariables.

# %%
### TODO: update if need be
#import standard pacakges 
import numpy as np #needed for reshaping arrays 
import matplotlib.pyplot as plt #for rendering plots
import tensorflow as tf #for

# %% [markdown]
# ## Importing the `cfl` package
#
# Type `import cfl` in order to import the entire `cfl` package, or import the specific modules you intend to use.

# %%
# importing cfl will import all of the sub-modules inside of cfl as well
import cfl

# you can also import specific files, functions, or classes
# into the local namespace 
from cfl.cfl_wrapper import make_CFL
from cfl.save.experiment_saver import ExperimentSaver
from cfl.dataset import Dataset

# %% [markdown]
# ## Visual Bars Data
#
# For this experiment, we will use the Visual Bars dataset (from Chalupka 2015).
#
# The causal dataset consists of a set of binary (black-and-white) images. These images each have a black background
# and contain white pixels of random noise. Each image may also contain either a white vertical and/or a horizontal bar.
#
# The effect dataset (aka the "Target") is, in this case, a single dimensional binary variable. In other words, there is only one variable in the target data set, and that variable can either be a "0" or a "1".
#
#
# The underlying causal structure used to generate the visual bars images includes two 'hidden variables', the contents of each image, and the target's value. The values of hidden variables are not observed directly in the data set, but they impact the values of variables that we do observe.
#
# The $H_{1}$ hidden variable being "on" deterministically causes a vertical bar to be present in the image. If the hidden variable is on, the vertical bar is present in the image. It also increases the probability that the target variable will be "on." The $H_{2}$ hidden variable causes a horizontal bar to be present in the image, but does not directly impact the value of the target. In an image, the presence of a horizontal bar increases the probability of the target being on, but the presence of a vertical bar does not directly increase the probability of the target being on.
#
# Below, these relationships are shown as a causal graph. The solid circles are the observed variables, the dotted lines are hidden (unobserved) variables, and the arrows denote a causal relationship from one variable to another.
#
# <img src="img/VisualBarsCausal.png" alt="causal graph for visual bars" height="200"/>
#
#
# Wow! All that's a little confusing. What does it mean?
#
# Basically, this means that there is confounding in our set-up! You can see in the image above that $H_{1}$ has influence on both the images and the target directly. And confounding makes disentangling the causal relationships a little more complicated.
#
#
# So we want CFL to separate the images in our data set into 4 observational classes: one for each combination of values for H1 and H2. This will allow later experimenters to intervene across these boundaries and determine which of the differences in the images are causally important (the horizontal bars) versus predictive but not causal (the vertical bars)
#
#
# The table below shows the 'ground truth' probability of the target value being on, given each possible state of the hidden variables. These values are used to generate the target values. We want to recover these probabilities as accurately as possible by the end of the density estimation step of CFL, and recover these four categories by the end of the clustering step.
#
# <img src="img/VisualBarsProbs.png" alt="probability table for visual bars" height="150"/>

# %% [markdown]
# ## Loading Visual Bars Data
#
# In order to create a visual bars data set (ie a set of images and associated target values), we need to import the file `generate_visual_bars_data.py`. If you are trying to generate the visual bars data from somewhere outside the root directory of the reposity, add the visual_bars_test directory path to the PYTHONPATH (same as you did for the `cfl` package) for easy importing.

# %%
#import the file to generate visual bars data 
import visual_bars_test.generate_visual_bars_data as vbd

# uncomment this line if you have added visual_bars_test to the pythonpath
# import generate_visual_bars_data as vbd

# %% [markdown]
# In order to generate visual bars data, we set the number of images we want to generate (`n_samples`), the size of each image in pixels (`im_shape`), and the intensity of random noise in the image (`noise_lvl`). To have reproducible results, we also will set a random seed.

# %%
n_samples = 1000
im_shape = (10, 10)
noise_lvl= 0.03
set_seed = 180

# create visual bars data 
vb_data = vbd.VisualBarsData(n_samples=n_samples, im_shape = im_shape, noise_lvl=noise_lvl, set_random_seed=set_seed)

# visualize some example images 
vb_data.viewSingleImage()
vb_data.viewSingleImage()
vb_data.viewSingleImage()

# %% [markdown]
# We save the images to a variable `X` and the array of target behavior to a variable `Y`. Note that `X` and `Y` are aligned - they have the same number of observations, and the nth image in `X` corresponds to the nth target value in `Y`.

# %%
# retrieve the images and the target 
X = vb_data.getImages()
Y = vb_data.getTarget()

# X and Y have the same number of rows  
print(X.shape)
print(Y.shape)
print(X.shape[0]==Y.shape[0])
# Out:
# (1000, 10, 10)
# (1000,)
# True

# %% [markdown]
# Finally, we reshape the `X` and `Y` into the right shapes to be passed through the conditional density estimation (CDE) step of CFL. Because the density estimation model we will use, `CondExp`, takes in 1-dimensional input, we need to flatten the 2D images into 1D before passing `X` in. NOTE: not all CDEs need the same input shape! Most take in 1D inputs, but a convolutional neural net (CNN), take in 2-D input. If we were using a CNN, we would not flatten `X`.
#
# We then expand `Y` because Tensorflow expects 2 dimensions, where the first dimension is samples and the second is features. So expanding to 2 dimensions is makes the shape (n_samples, 1)instead of (n_samples,).

# %%
#reformat x, y into the right shape for the neural net 
X = np.reshape(X, (X.shape[0], X.shape[1]*X.shape[2])) 
Y = np.expand_dims(Y, -1)
print(X.shape)
print(Y.shape)
# Out:
# (1000, 100)
# (1000, 1)

# %% [markdown]
# ## Key Points: Loading Data
# - should have a data set X and a data set Y that are aligned (each row in X corresponds to the row with the same index in Y)
# - For most instances of CFL, X and Y should be reshaped st that each one is a 2D array, where the first dimension is samples/observations and the second dimension is all the features

# %% [markdown]
# ## Saving Results
#
# We will now set up an experiment saver. This will save not only the results from each step of CFL, but also the parameters input to CFL.
#
# We will also pass the X and Y data into a Dataset object. Then, every time we pass that Dataset through any part of the CFL pipeline, the results will automatically be stored in a directory associated with that Dataset.

# %%
# save experiment results from this CFL configuration across all datasets to 'results/visual_bars/experiment000x'
experiment_saver = ExperimentSaver('results/visual_bars')

# construct dataset. this will save all dataset-specific results to 'results/visual_bars/experiment000x/dataset0'
dataset0 = Dataset(X, Y, dataset_label='dataset0', experiment_saver=experiment_saver)
# Out:
# All results from this run will be saved to results/visual_bars\experiment0002

# %% [markdown]
# ## Training and Predicting with a CFL object
#
# Now we're ready to go!
#
# First, CFL takes in several sets of parameters, each in dictionary form:
# - data_info
# - CDE_params
# - cluster_params
#
# For further details on the meaning of these parameters, consult the documentation for the clusterer and the CondExp base class.
#
# Note that not all of the CDE_params listed here need to be specified - if they are not specified, default values will be provided.

# %%
# set all CFL parameters

# generic data parameters
data_info = { 'X_dims' : X.shape, 
              'Y_dims' : Y.shape } 

# conditional density estimator parameters
lr = 1e-4
CDE_params = { 'batch_size'  : 128,
               'optimizer'   : 'adam',
               'n_epochs'    : 100,
               'verbose'     : 1,
               'opt_config'  : {'lr': 1e-4}
               'dense_units' : [1024, 1024, data_info['Y_dims'][1]],
               'activations' : ['linear', 'linear', 'linear'],
               'dropouts'    : [0.2, 0.5, 0.5], 
               'show_plot'   : False }

    
# clusterer parameters
cluster_params = { 'n_Xclusters' : 4, 
                   'n_Yclusters' : 4 }

# %% [markdown]
# Then we make the cfl object with the `make_CFL` function! This is a function that allows you to create both parts of the cfl model in one step. It takes in the parameter dictionaries, and strings specifying which type of CDE/ clusterer to use.

# %%
# build CFL object! 
cfl_object = make_CFL(  data_info=data_info, 
                        CDE_type='CondExpMod', 
                        cluster_type='Kmeans', 
                        CDE_params=CDE_params, 
                        cluster_params=cluster_params,
                        experiment_saver=experiment_saver)
# Out:
# opt_config not specified in params, defaulting to {}
# weights_path not specified in params, defaulting to None
# loss not specified in params, defaulting to mean_squared_error

# %% [markdown]
# We train the CFL object on our data.
# The results are in the form `(x labels, y labels, train loss, test loss)`.
# The x labels and y labels are the macrovariable labels for each sample in the X and Y data set, respectively,
# and the trian and test losses are the losses from the density estimation step of training.

# %%
train_results = cfl_object.train(dataset0, standardize=True)
# Out:
# Train on 750 samples, validate on 250 samples
# Epoch 1/100
# 750/750 [==============================] - 1s 727us/sample - loss: 6.8227 - val_loss: 2.8269
# Epoch 2/100
# 750/750 [==============================] - 0s 247us/sample - loss: 4.9828 - val_loss: 2.2185
# Epoch 3/100
# 750/750 [==============================] - 0s 227us/sample - loss: 5.0978 - val_loss: 1.3500
# Epoch 4/100
# 750/750 [==============================] - 0s 151us/sample - loss: 3.6224 - val_loss: 1.9322
# Epoch 5/100
# 750/750 [==============================] - 0s 247us/sample - loss: 2.5106 - val_loss: 1.1400
# Epoch 6/100
# 750/750 [==============================] - 0s 286us/sample - loss: 2.7343 - val_loss: 1.1324
# Epoch 7/100
# 750/750 [==============================] - 0s 137us/sample - loss: 2.4766 - val_loss: 1.1849
# Epoch 8/100
# 750/750 [==============================] - 0s 255us/sample - loss: 2.2217 - val_loss: 0.9893
# Epoch 9/100
# 750/750 [==============================] - 0s 292us/sample - loss: 2.0689 - val_loss: 0.9637
# Epoch 10/100
# 750/750 [==============================] - 0s 248us/sample - loss: 2.0351 - val_loss: 0.9226
# Epoch 11/100
# 750/750 [==============================] - 0s 124us/sample - loss: 1.8767 - val_loss: 1.0676
# Epoch 12/100
# 750/750 [==============================] - 0s 291us/sample - loss: 1.8352 - val_loss: 0.8927
# Epoch 13/100
# 750/750 [==============================] - 0s 260us/sample - loss: 1.8372 - val_loss: 0.8919
# Epoch 14/100
# 750/750 [==============================] - 0s 141us/sample - loss: 1.5451 - val_loss: 1.0459
# Epoch 15/100
# 750/750 [==============================] - 0s 233us/sample - loss: 1.6075 - val_loss: 0.8853
# Epoch 16/100
# 750/750 [==============================] - 0s 229us/sample - loss: 1.3876 - val_loss: 0.8618
# Epoch 17/100
# 750/750 [==============================] - 0s 165us/sample - loss: 1.5548 - val_loss: 0.8808
# Epoch 18/100
# 750/750 [==============================] - 0s 129us/sample - loss: 1.4248 - val_loss: 0.8885
# Epoch 19/100
# 750/750 [==============================] - 0s 277us/sample - loss: 1.3533 - val_loss: 0.8079
# Epoch 20/100
# 750/750 [==============================] - 0s 151us/sample - loss: 1.4415 - val_loss: 0.8272
# Epoch 21/100
# 750/750 [==============================] - 0s 159us/sample - loss: 1.1987 - val_loss: 0.8161
# Epoch 22/100
# 750/750 [==============================] - 0s 260us/sample - loss: 1.2275 - val_loss: 0.7432
# Epoch 23/100
# 750/750 [==============================] - 0s 143us/sample - loss: 1.3049 - val_loss: 0.7583
# Epoch 24/100
# 750/750 [==============================] - 0s 123us/sample - loss: 1.1152 - val_loss: 0.7524
# Epoch 25/100
# 750/750 [==============================] - 0s 127us/sample - loss: 1.1959 - val_loss: 0.8528
# Epoch 26/100
# 750/750 [==============================] - 0s 123us/sample - loss: 1.1289 - val_loss: 0.7749
# Epoch 27/100
# 750/750 [==============================] - 0s 120us/sample - loss: 1.2124 - val_loss: 0.7519
# Epoch 28/100
# 750/750 [==============================] - 0s 120us/sample - loss: 1.0754 - val_loss: 0.7923
# Epoch 29/100
# 750/750 [==============================] - 0s 113us/sample - loss: 1.1634 - val_loss: 0.7808
# Epoch 30/100
# 750/750 [==============================] - 0s 195us/sample - loss: 1.1692 - val_loss: 0.7298
# Epoch 31/100
# 750/750 [==============================] - 0s 111us/sample - loss: 1.0281 - val_loss: 0.7764
# Epoch 32/100
# 750/750 [==============================] - 0s 227us/sample - loss: 1.0789 - val_loss: 0.7241
# Epoch 33/100
# 750/750 [==============================] - 0s 288us/sample - loss: 0.9323 - val_loss: 0.7190
# Epoch 34/100
# 750/750 [==============================] - 0s 147us/sample - loss: 1.0727 - val_loss: 0.7723
# Epoch 35/100
# 750/750 [==============================] - 0s 109us/sample - loss: 0.9662 - val_loss: 0.7729
# Epoch 36/100
# 750/750 [==============================] - 0s 111us/sample - loss: 0.9970 - val_loss: 0.7408
# Epoch 37/100
# 750/750 [==============================] - 0s 108us/sample - loss: 0.9676 - val_loss: 0.7496
# Epoch 38/100
# 750/750 [==============================] - 0s 115us/sample - loss: 0.9589 - val_loss: 0.7194
# Epoch 39/100
# 750/750 [==============================] - 0s 116us/sample - loss: 0.9305 - val_loss: 0.7452
# Epoch 40/100
# 750/750 [==============================] - 0s 242us/sample - loss: 0.9275 - val_loss: 0.7149
# Epoch 41/100
# 750/750 [==============================] - 0s 127us/sample - loss: 0.9499 - val_loss: 0.7423
# Epoch 42/100
# 750/750 [==============================] - 0s 107us/sample - loss: 0.9705 - val_loss: 0.7277
# Epoch 43/100
# 750/750 [==============================] - 0s 107us/sample - loss: 0.9218 - val_loss: 0.7397
# Epoch 44/100
# 750/750 [==============================] - 0s 127us/sample - loss: 0.9039 - val_loss: 0.7513
# Epoch 45/100
# 750/750 [==============================] - 0s 121us/sample - loss: 0.9170 - val_loss: 0.7246
# Epoch 46/100
# 750/750 [==============================] - 0s 127us/sample - loss: 0.8544 - val_loss: 0.7319
# Epoch 47/100
# 750/750 [==============================] - 0s 255us/sample - loss: 0.8656 - val_loss: 0.7135
# Epoch 48/100
# 750/750 [==============================] - 0s 295us/sample - loss: 0.9049 - val_loss: 0.7093
# Epoch 49/100
# 750/750 [==============================] - 0s 269us/sample - loss: 0.8754 - val_loss: 0.6895
# Epoch 50/100
# 750/750 [==============================] - 0s 153us/sample - loss: 0.8392 - val_loss: 0.7045
# Epoch 51/100
# 750/750 [==============================] - 0s 131us/sample - loss: 0.8634 - val_loss: 0.7180
# Epoch 52/100
# 750/750 [==============================] - 0s 127us/sample - loss: 0.8708 - val_loss: 0.7312
# Epoch 53/100
# 750/750 [==============================] - 0s 129us/sample - loss: 0.9027 - val_loss: 0.7236
# Epoch 54/100
# 750/750 [==============================] - 0s 137us/sample - loss: 0.8282 - val_loss: 0.7068
# Epoch 55/100
# 750/750 [==============================] - 0s 281us/sample - loss: 0.8440 - val_loss: 0.6886
# Epoch 56/100
# 750/750 [==============================] - 0s 136us/sample - loss: 0.8317 - val_loss: 0.7037
# Epoch 57/100
# 750/750 [==============================] - 0s 135us/sample - loss: 0.8664 - val_loss: 0.7347
# Epoch 58/100
# 750/750 [==============================] - 0s 132us/sample - loss: 0.8507 - val_loss: 0.7471
# Epoch 59/100
# 750/750 [==============================] - 0s 125us/sample - loss: 0.7979 - val_loss: 0.7272
# Epoch 60/100
# 750/750 [==============================] - 0s 125us/sample - loss: 0.8457 - val_loss: 0.7319
# Epoch 61/100
# 750/750 [==============================] - 0s 125us/sample - loss: 0.8330 - val_loss: 0.7220
# Epoch 62/100
# 750/750 [==============================] - 0s 123us/sample - loss: 0.8311 - val_loss: 0.7204
# Epoch 63/100
# 750/750 [==============================] - 0s 128us/sample - loss: 0.8291 - val_loss: 0.7242
# Epoch 64/100
# 750/750 [==============================] - 0s 129us/sample - loss: 0.8492 - val_loss: 0.7303
# Epoch 65/100
# 750/750 [==============================] - 0s 132us/sample - loss: 0.8192 - val_loss: 0.7274
# Epoch 66/100
# 750/750 [==============================] - 0s 131us/sample - loss: 0.8265 - val_loss: 0.7062
# Epoch 67/100
# 750/750 [==============================] - 0s 139us/sample - loss: 0.8177 - val_loss: 0.6891
# Epoch 68/100
# 750/750 [==============================] - 0s 124us/sample - loss: 0.8334 - val_loss: 0.7070
# Epoch 69/100
# 750/750 [==============================] - 0s 109us/sample - loss: 0.8234 - val_loss: 0.7265
# Epoch 70/100
# 750/750 [==============================] - 0s 144us/sample - loss: 0.8224 - val_loss: 0.7371
# Epoch 71/100
# 750/750 [==============================] - 0s 141us/sample - loss: 0.8158 - val_loss: 0.7296
# Epoch 72/100
# 750/750 [==============================] - 0s 109us/sample - loss: 0.8031 - val_loss: 0.7239
# Epoch 73/100
# 750/750 [==============================] - 0s 128us/sample - loss: 0.8144 - val_loss: 0.7360
# Epoch 74/100
# 750/750 [==============================] - 0s 129us/sample - loss: 0.8026 - val_loss: 0.7469
# Epoch 75/100
# 750/750 [==============================] - 0s 115us/sample - loss: 0.7703 - val_loss: 0.7360
# Epoch 76/100
# 750/750 [==============================] - 0s 128us/sample - loss: 0.8350 - val_loss: 0.7326
# Epoch 77/100
# 750/750 [==============================] - 0s 128us/sample - loss: 0.7889 - val_loss: 0.7224
# Epoch 78/100
# 750/750 [==============================] - 0s 131us/sample - loss: 0.8120 - val_loss: 0.7114
# Epoch 79/100
# 750/750 [==============================] - 0s 128us/sample - loss: 0.8198 - val_loss: 0.7167
# Epoch 80/100
# 750/750 [==============================] - 0s 123us/sample - loss: 0.8134 - val_loss: 0.7252
# Epoch 81/100
# 750/750 [==============================] - 0s 128us/sample - loss: 0.7723 - val_loss: 0.7279
# Epoch 82/100
# 750/750 [==============================] - 0s 127us/sample - loss: 0.7774 - val_loss: 0.7290
# Epoch 83/100
# 750/750 [==============================] - 0s 124us/sample - loss: 0.7963 - val_loss: 0.7303
# Epoch 84/100
# 750/750 [==============================] - 0s 129us/sample - loss: 0.7773 - val_loss: 0.7258
# Epoch 85/100
# 750/750 [==============================] - 0s 140us/sample - loss: 0.7943 - val_loss: 0.7247
# Epoch 86/100
# 750/750 [==============================] - 0s 132us/sample - loss: 0.7792 - val_loss: 0.7286
# Epoch 87/100
# 750/750 [==============================] - 0s 153us/sample - loss: 0.8115 - val_loss: 0.7357
# Epoch 88/100
# 750/750 [==============================] - 0s 125us/sample - loss: 0.7922 - val_loss: 0.7195
# Epoch 89/100
# 750/750 [==============================] - 0s 131us/sample - loss: 0.8104 - val_loss: 0.7215
# Epoch 90/100
# 750/750 [==============================] - 0s 132us/sample - loss: 0.7869 - val_loss: 0.7314
# Epoch 91/100
# 750/750 [==============================] - 0s 120us/sample - loss: 0.7865 - val_loss: 0.7244
# Epoch 92/100
# 750/750 [==============================] - 0s 129us/sample - loss: 0.7901 - val_loss: 0.7128
# Epoch 93/100
# 750/750 [==============================] - 0s 173us/sample - loss: 0.7965 - val_loss: 0.7134
# Epoch 94/100
# 750/750 [==============================] - 0s 131us/sample - loss: 0.7967 - val_loss: 0.7355
# Epoch 95/100
# 750/750 [==============================] - 0s 127us/sample - loss: 0.7863 - val_loss: 0.7250
# Epoch 96/100
# 750/750 [==============================] - 0s 135us/sample - loss: 0.8001 - val_loss: 0.7177
# Epoch 97/100
# 750/750 [==============================] - 0s 124us/sample - loss: 0.7838 - val_loss: 0.7283
# Epoch 98/100
# 750/750 [==============================] - 0s 132us/sample - loss: 0.8190 - val_loss: 0.7289
# Epoch 99/100
# 750/750 [==============================] - 0s 124us/sample - loss: 0.7812 - val_loss: 0.7250
# Epoch 100/100
# 750/750 [==============================] - 0s 117us/sample - loss: 0.7833 - val_loss: 0.7150
# Loading parameters from  results/visual_bars\experiment0002\dataset0\checkpoints/best_weights
# 100%|██████████| 1000/1000 [00:00<00:00, 6801.31it/s]

# %%
# make second dataset for prediction
dataset1 = Dataset(X[:100,:], Y[:100,:], dataset_label='dataset1', experiment_saver=experiment_saver) 
# note: drawing from the same data as dataset0 for now for sake of demonstration

# %%
pyx = cfl_object.predict(dataset1)

# %% [markdown]
# ## Visualize Results

# %% [markdown]
# We can view some images with their predicted label using the `viewImages` function. As we can see, the results are pretty inconsistent - multiple images that should be in the same class are part of different classes. This is in part because our sample size is not quite large enough for CFL to learn it very well. Try this experiment again with a larger sample size and see how the results change. You can also try with a different type of density estimator.

# %%
vb_data.viewImages(n_images=50, x_lbls=train_results[0][:50])

# %% [markdown]
# ## Beyond the Basics: Training and predicting with just the conditional density or just with clustering
#
# In some cases, you may not want to perform both steps of CFL on your data, but rather just one of the steps. In that case, you need to make the CDE or clusterer object individually.

# %%
# generic data parameters
data_info = { 'X_dims' : X.shape, 
              'Y_dims' : Y.shape } 

# conditional density estimator parameters
CDE_params = { 'batch_size'  : 128,
               'optimizer'   : 'adam',
               'n_epochs'    : 100,
               'verbose'     : 1,
               'dense_units' : [1024, 1024, data_info['Y_dims'][1]],
               'activations' : ['linear', 'linear', 'linear'],
               'dropouts'    : [0.2, 0.5, 0.5], 
               'show_plot'   : False }

# construct a CDE object (no saver specified - results will not be saved)
CDE_object = cfl.density_estimation_methods.condExp.CondExp(data_info, CDE_params)

CDE_object.train(dataset0, standardize=False, best=True)

pyx = CDE_object.predict(dataset0)
truth = vb_data.getGroundTruth()


#plot 
fig = plt.figure()
plot_idx = np.random.choice(pyx.shape[0], 1000, replace=False)
plt.scatter(range(1000), pyx[plot_idx], c=truth[plot_idx])
plt.show()

for i in range(4):
    print('Average prediction for x-class {}: {:.2f}'.format(i, np.mean(pyx[truth==i])))
# Out:
# opt_config not specified in params, defaulting to {}
# weights_path not specified in params, defaulting to None
# loss not specified in params, defaulting to mean_squared_error
# You have not provided an ExperimentSaver. Your may continue to run CFL but your configuration will not be saved.
# Train on 750 samples, validate on 250 samples
# Epoch 1/100
# 750/750 [==============================] - 1s 2ms/sample - loss: 5.5844 - val_loss: 0.8147
# Epoch 2/100
# 750/750 [==============================] - 0s 119us/sample - loss: 4.8409 - val_loss: 0.5746
# Epoch 3/100
# 750/750 [==============================] - 0s 121us/sample - loss: 4.1017 - val_loss: 0.4536
# Epoch 4/100
# 750/750 [==============================] - 0s 152us/sample - loss: 3.7067 - val_loss: 0.3566
# Epoch 5/100
# 750/750 [==============================] - 0s 163us/sample - loss: 3.1615 - val_loss: 0.3057
# Epoch 6/100
# 750/750 [==============================] - 0s 151us/sample - loss: 2.8697 - val_loss: 0.2887
# Epoch 7/100
# 750/750 [==============================] - 0s 167us/sample - loss: 2.6574 - val_loss: 0.2808
# Epoch 8/100
# 750/750 [==============================] - 0s 161us/sample - loss: 2.4592 - val_loss: 0.2680
# Epoch 9/100
# 750/750 [==============================] - 0s 142us/sample - loss: 2.2945 - val_loss: 0.2494
# Epoch 10/100
# 750/750 [==============================] - 0s 160us/sample - loss: 2.1353 - val_loss: 0.2367
# Epoch 11/100
# 750/750 [==============================] - 0s 142us/sample - loss: 2.0313 - val_loss: 0.2304
# Epoch 12/100
# 750/750 [==============================] - 0s 121us/sample - loss: 1.8495 - val_loss: 0.2286
# Epoch 13/100
# 750/750 [==============================] - 0s 133us/sample - loss: 1.8561 - val_loss: 0.2248
# Epoch 14/100
# 750/750 [==============================] - 0s 138us/sample - loss: 1.6214 - val_loss: 0.2233
# Epoch 15/100
# 750/750 [==============================] - 0s 65us/sample - loss: 1.7055 - val_loss: 0.2236
# Epoch 16/100
# 750/750 [==============================] - 0s 130us/sample - loss: 1.4845 - val_loss: 0.2215
# Epoch 17/100
# 750/750 [==============================] - 0s 102us/sample - loss: 1.4535 - val_loss: 0.2161
# Epoch 18/100
# 750/750 [==============================] - 0s 96us/sample - loss: 1.5019 - val_loss: 0.2145
# Epoch 19/100
# 750/750 [==============================] - 0s 47us/sample - loss: 1.3333 - val_loss: 0.2149
# Epoch 20/100
# 750/750 [==============================] - 0s 124us/sample - loss: 1.5322 - val_loss: 0.2132
# Epoch 21/100
# 750/750 [==============================] - 0s 101us/sample - loss: 1.2705 - val_loss: 0.2067
# Epoch 22/100
# 750/750 [==============================] - 0s 109us/sample - loss: 1.1777 - val_loss: 0.2019
# Epoch 23/100
# 750/750 [==============================] - 0s 103us/sample - loss: 1.1756 - val_loss: 0.2006
# Epoch 24/100
# 750/750 [==============================] - 0s 52us/sample - loss: 1.2023 - val_loss: 0.2008
# Epoch 25/100
# 750/750 [==============================] - 0s 52us/sample - loss: 1.1373 - val_loss: 0.2026
# Epoch 26/100
# 750/750 [==============================] - 0s 52us/sample - loss: 1.1066 - val_loss: 0.2022
# Epoch 27/100
# 750/750 [==============================] - 0s 56us/sample - loss: 0.9977 - val_loss: 0.2022
# Epoch 28/100
# 750/750 [==============================] - 0s 48us/sample - loss: 0.9910 - val_loss: 0.2016
# Epoch 29/100
# 750/750 [==============================] - 0s 116us/sample - loss: 0.9779 - val_loss: 0.2000
# Epoch 30/100
# 750/750 [==============================] - 0s 124us/sample - loss: 0.8585 - val_loss: 0.1971
# Epoch 31/100
# 750/750 [==============================] - 0s 124us/sample - loss: 0.9468 - val_loss: 0.1943
# Epoch 32/100
# 750/750 [==============================] - 0s 132us/sample - loss: 0.8308 - val_loss: 0.1923
# Epoch 33/100
# 750/750 [==============================] - 0s 129us/sample - loss: 0.8337 - val_loss: 0.1922
# Epoch 34/100
# 750/750 [==============================] - 0s 124us/sample - loss: 0.8412 - val_loss: 0.1921
# Epoch 35/100
# 750/750 [==============================] - 0s 126us/sample - loss: 0.7952 - val_loss: 0.1912
# Epoch 36/100
# 750/750 [==============================] - 0s 137us/sample - loss: 0.8185 - val_loss: 0.1894
# Epoch 37/100
# 750/750 [==============================] - 0s 56us/sample - loss: 0.7755 - val_loss: 0.1898
# Epoch 38/100
# 750/750 [==============================] - 0s 54us/sample - loss: 0.7323 - val_loss: 0.1904
# Epoch 39/100
# 750/750 [==============================] - 0s 107us/sample - loss: 0.7142 - val_loss: 0.1890
# Epoch 40/100
# 750/750 [==============================] - 0s 135us/sample - loss: 0.7761 - val_loss: 0.1884
# Epoch 41/100
# 750/750 [==============================] - 0s 58us/sample - loss: 0.7924 - val_loss: 0.1888
# Epoch 42/100
# 750/750 [==============================] - 0s 111us/sample - loss: 0.7403 - val_loss: 0.1882
# Epoch 43/100
# 750/750 [==============================] - 0s 119us/sample - loss: 0.7377 - val_loss: 0.1872
# Epoch 44/100
# 750/750 [==============================] - 0s 138us/sample - loss: 0.6694 - val_loss: 0.1868
# Epoch 45/100
# 750/750 [==============================] - 0s 60us/sample - loss: 0.6485 - val_loss: 0.1880
# Epoch 46/100
# 750/750 [==============================] - 0s 52us/sample - loss: 0.6506 - val_loss: 0.1897
# Epoch 47/100
# 750/750 [==============================] - 0s 59us/sample - loss: 0.5916 - val_loss: 0.1895
# Epoch 48/100
# 750/750 [==============================] - 0s 51us/sample - loss: 0.6081 - val_loss: 0.1886
# Epoch 49/100
# 750/750 [==============================] - 0s 52us/sample - loss: 0.6072 - val_loss: 0.1871
# Epoch 50/100
# 750/750 [==============================] - 0s 117us/sample - loss: 0.5853 - val_loss: 0.1863
# Epoch 51/100
# 750/750 [==============================] - 0s 54us/sample - loss: 0.6135 - val_loss: 0.1867
# Epoch 52/100
# 750/750 [==============================] - 0s 53us/sample - loss: 0.5842 - val_loss: 0.1873
# Epoch 53/100
# 750/750 [==============================] - 0s 55us/sample - loss: 0.5427 - val_loss: 0.1874
# Epoch 54/100
# 750/750 [==============================] - 0s 124us/sample - loss: 0.5483 - val_loss: 0.1873
# Epoch 55/100
# 750/750 [==============================] - 0s 79us/sample - loss: 0.5971 - val_loss: 0.1866
# Epoch 56/100
# 750/750 [==============================] - 0s 51us/sample - loss: 0.4663 - val_loss: 0.1868
# Epoch 57/100
# 750/750 [==============================] - 0s 59us/sample - loss: 0.5316 - val_loss: 0.1878
# Epoch 58/100
# 750/750 [==============================] - 0s 54us/sample - loss: 0.5457 - val_loss: 0.1881
# Epoch 59/100
# 750/750 [==============================] - 0s 53us/sample - loss: 0.5589 - val_loss: 0.1880
# Epoch 60/100
# 750/750 [==============================] - 0s 53us/sample - loss: 0.5132 - val_loss: 0.1872
# Epoch 61/100
# 750/750 [==============================] - 0s 52us/sample - loss: 0.4932 - val_loss: 0.1875
# Epoch 62/100
# 750/750 [==============================] - 0s 57us/sample - loss: 0.5141 - val_loss: 0.1872
# Epoch 63/100
# 750/750 [==============================] - 0s 63us/sample - loss: 0.4890 - val_loss: 0.1871
# Epoch 64/100
# 750/750 [==============================] - 0s 63us/sample - loss: 0.5029 - val_loss: 0.1876
# Epoch 65/100
# 750/750 [==============================] - 0s 56us/sample - loss: 0.5014 - val_loss: 0.1882
# Epoch 66/100
# 750/750 [==============================] - 0s 54us/sample - loss: 0.4597 - val_loss: 0.1890
# Epoch 67/100
# 750/750 [==============================] - 0s 60us/sample - loss: 0.4656 - val_loss: 0.1887
# Epoch 68/100
# 750/750 [==============================] - 0s 54us/sample - loss: 0.4516 - val_loss: 0.1878
# Epoch 69/100
# 750/750 [==============================] - 0s 51us/sample - loss: 0.4612 - val_loss: 0.1875
# Epoch 70/100
# 750/750 [==============================] - 0s 55us/sample - loss: 0.4574 - val_loss: 0.1869
# Epoch 71/100
# 750/750 [==============================] - 0s 52us/sample - loss: 0.4571 - val_loss: 0.1864
# Epoch 72/100
# 750/750 [==============================] - 0s 127us/sample - loss: 0.4506 - val_loss: 0.1855
# Epoch 73/100
# 750/750 [==============================] - 0s 109us/sample - loss: 0.4343 - val_loss: 0.1853
# Epoch 74/100
# 750/750 [==============================] - 0s 48us/sample - loss: 0.4005 - val_loss: 0.1857
# Epoch 75/100
# 750/750 [==============================] - 0s 60us/sample - loss: 0.4098 - val_loss: 0.1856
# Epoch 76/100
# 750/750 [==============================] - 0s 63us/sample - loss: 0.4187 - val_loss: 0.1858
# Epoch 77/100
# 750/750 [==============================] - 0s 58us/sample - loss: 0.4128 - val_loss: 0.1867
# Epoch 78/100
# 750/750 [==============================] - 0s 57us/sample - loss: 0.4346 - val_loss: 0.1877
# Epoch 79/100
# 750/750 [==============================] - 0s 55us/sample - loss: 0.4232 - val_loss: 0.1874
# Epoch 80/100
# 750/750 [==============================] - 0s 55us/sample - loss: 0.3977 - val_loss: 0.1863
# Epoch 81/100
# 750/750 [==============================] - 0s 54us/sample - loss: 0.4143 - val_loss: 0.1861
# Epoch 82/100
# 750/750 [==============================] - 0s 53us/sample - loss: 0.3762 - val_loss: 0.1858
# Epoch 83/100
# 750/750 [==============================] - 0s 52us/sample - loss: 0.3698 - val_loss: 0.1856
# Epoch 84/100
# 750/750 [==============================] - 0s 121us/sample - loss: 0.3849 - val_loss: 0.1849
# Epoch 85/100
# 750/750 [==============================] - 0s 116us/sample - loss: 0.3880 - val_loss: 0.1845
# Epoch 86/100
# 750/750 [==============================] - 0s 54us/sample - loss: 0.3857 - val_loss: 0.1850
# Epoch 87/100
# 750/750 [==============================] - 0s 55us/sample - loss: 0.3823 - val_loss: 0.1856
# Epoch 88/100
# 750/750 [==============================] - 0s 51us/sample - loss: 0.3633 - val_loss: 0.1862
# Epoch 89/100
# 750/750 [==============================] - 0s 59us/sample - loss: 0.3447 - val_loss: 0.1861
# Epoch 90/100
# 750/750 [==============================] - 0s 53us/sample - loss: 0.3857 - val_loss: 0.1854
# Epoch 91/100
# 750/750 [==============================] - 0s 54us/sample - loss: 0.3479 - val_loss: 0.1851
# Epoch 92/100
# 750/750 [==============================] - 0s 50us/sample - loss: 0.3477 - val_loss: 0.1849
# Epoch 93/100
# 750/750 [==============================] - 0s 51us/sample - loss: 0.3639 - val_loss: 0.1850
# Epoch 94/100
# 750/750 [==============================] - 0s 53us/sample - loss: 0.3577 - val_loss: 0.1852
# Epoch 95/100
# 750/750 [==============================] - 0s 109us/sample - loss: 0.3628 - val_loss: 0.1854
# Epoch 96/100
# 750/750 [==============================] - 0s 56us/sample - loss: 0.3375 - val_loss: 0.1850
# Epoch 97/100
# 750/750 [==============================] - 0s 51us/sample - loss: 0.3516 - val_loss: 0.1849
# Epoch 98/100
# 750/750 [==============================] - 0s 51us/sample - loss: 0.3307 - val_loss: 0.1852
# Epoch 99/100
# 750/750 [==============================] - 0s 65us/sample - loss: 0.3549 - val_loss: 0.1849
# Epoch 100/100
# 750/750 [==============================] - 0s 114us/sample - loss: 0.3260 - val_loss: 0.1842
# Loading parameters from  results/visual_bars\experiment0002\dataset0\checkpoints/best_weights
# Average prediction for x-class 0: 0.32
# Average prediction for x-class 1: 0.52
# Average prediction for x-class 2: 0.53
# Average prediction for x-class 3: 0.70

# %%
from cfl.visualization_methods.visualization import visualize

# %%
FIG_KWARGS = {} 
X_KWARGS = { 'cmap' : 'BrBG_r' }
Y_KWARGS = {'cmap' : 'coolwarm' }
visualize(X, Y, x_lbls=train_results[0], y_lbls=train_results[1], fig_kwargs=FIG_KWARGS, X_kwargs=X_KWARGS, Y_kwargs=Y_KWARGS)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-700ba89faf56> in <module>
#       2 X_KWARGS = { 'cmap' : 'BrBG_r' }
#       3 Y_KWARGS = {'cmap' : 'coolwarm' }
# ----> 4 visualize(X, Y, x_lbls=train_results[0], y_lbls=train_results[1], fig_kwargs=FIG_KWARGS, X_kwargs=X_KWARGS, Y_kwargs=Y_KWARGS)
#
# c:\Users\yumen\Documents\Schmidt Academy\cfl\cfl\visualization_methods\visualization.py in visualize(X, Y, x_lbls, y_lbls, fig_kwargs, X_kwargs, Y_kwargs)
#      39     '''
#      40     fig = plt.figure(**fig_kwargs)
# ---> 41     visualize_helper(0, X, x_lbls, X_kwargs) #  np.linspace(-4,4,30)) #'in subplot 0, draw the x-figure'
#      42     visualize_helper(1, Y, y_lbls, Y_kwargs) # np.linspace(-3,5.5,30))# 'in subplot 1, draw the y-figure'
#      43     fig.show()
#
# c:\Users\yumen\Documents\Schmidt Academy\cfl\cfl\visualization_methods\visualization.py in visualize_helper(col, data, lbls, kwargs)
#      58         ax = plt.subplot2grid((4,2), (cluster_id, col))
#      59         # Plot the cluster's mean difference from all frames' mean.
# ---> 60         cluster_mean = (data[lbls==cluster_id].mean(axis=0)-data.mean(axis=0)).reshape((Y_COORDS_LEN, X_COORDS_LEN)).T
#      61         ax.contourf(range(Y_COORDS_LEN), range(X_COORDS_LEN), cluster_mean , **kwargs)
#      62         ax.set_xticks([]); ax.set_yticks([])
#
# ValueError: cannot reshape array of size 100 into shape (55,9)
