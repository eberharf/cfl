# %%
# August 14, 2020

# %%
import CFL
import joblib

# %%
# load data
X, Y, coords = joblib.load('../el_nino/elnino_data.pkl')
# Out:
# /Users/imanwahle/anaconda2/envs/jntfpy3/lib/python3.6/site-packages/ipykernel_launcher.py:2: DeprecationWarning: The file '../el_nino/elnino_data.pkl' has been generated with a joblib version less than 0.10. Please regenerate this pickle file.

# %%
# initialize CFL object
el_nino = CFL.CFL(X, Y)

# %%
# train model
# el_nino.train_model()

# %%
# load weights
el_nino.load_weights('net_params/net')

# %%
# construct observational partitions
# x_scores, y_scores = el_nino.test_clustering()

# %%
# import matplotlib.pyplot as plt
# plt.plot(x_scores)
# plt.show()

# %%
# for xi in range(y_scores.shape[0]):
#     plt.plot(y_scores[xi])
#     plt.show()

# %%
# x_lbls, y_lbls = el_nino.create_clusters()

# %%
import numpy as np
el_nino.x_lbls = np.random.choice(range(4), (X.shape[0],))
el_nino.y_lbls = np.random.choice(range(4), (Y.shape[0],))

# %%
FIG_KWARGS = {'figsize' : (15,10), 'facecolor' : 'white'} #NOTE: these values are el nino-specific 
X_KWARGS = {'levels' : np.linspace(-4,4,30), 'cmap' : 'BrBG_r'}
Y_KWARGS = {'levels' : np.linspace(-3,5.5,30), 'cmap' : 'coolwarm'}

def visualize(X, Y, x_lbls, y_lbls, fig_kwargs=FIG_KWARGS, X_kwargs=X_KWARGS, Y_kwargs=Y_KWARGS)

# %%
# from time import sleep
# %%capture
# from tqdm import tqdm_notebook as tqdm
# tqdm().pandas()

# %%
# my_list = list(range(100))
# for x in tqdm(my_list):
#     sleep(0)
#     pass

# %%
el_nino.cluster.test_clustering(pyx, self.X, self.Y, 2, 5, 1, 4, 7, 1, cluster_method='KNN')
